# %% [markdown]
# <a href="https://colab.research.google.com/github/mattias71/colab_notebooks/blob/main/chapter1pyai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
def sigmoid(f):
  return 1/(1 +np.exp(-f))
f = np.linspace(-10, 10, 50)
print(f)
# Out:
# [-10.          -9.59183673  -9.18367347  -8.7755102   -8.36734694
#   -7.95918367  -7.55102041  -7.14285714  -6.73469388  -6.32653061
#   -5.91836735  -5.51020408  -5.10204082  -4.69387755  -4.28571429
#   -3.87755102  -3.46938776  -3.06122449  -2.65306122  -2.24489796
#   -1.83673469  -1.42857143  -1.02040816  -0.6122449   -0.20408163
#    0.20408163   0.6122449    1.02040816   1.42857143   1.83673469
#    2.24489796   2.65306122   3.06122449   3.46938776   3.87755102
#    4.28571429   4.69387755   5.10204082   5.51020408   5.91836735
#    6.32653061   6.73469388   7.14285714   7.55102041   7.95918367
#    8.36734694   8.7755102    9.18367347   9.59183673  10.        ]

# %%
g = np.round(sigmoid(f), 3)
g
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.   , 0.001, 0.001, 0.001,
#        0.002, 0.003, 0.004, 0.006, 0.009, 0.014, 0.02 , 0.03 , 0.045,
#        0.066, 0.096, 0.137, 0.193, 0.265, 0.352, 0.449, 0.551, 0.648,
#        0.735, 0.807, 0.863, 0.904, 0.934, 0.955, 0.97 , 0.98 , 0.986,
#        0.991, 0.994, 0.996, 0.997, 0.998, 0.999, 0.999, 0.999, 1.   ,
#        1.   , 1.   , 1.   , 1.   , 1.   ])

# %%
plt.plot(f ,g)
plt.xlabel("f")
plt.ylabel("g (sigmoid)")
# Out:
# Text(0, 0.5, 'g (sigmoid)')

# %%
g = np.tanh(f)
print(g)
plt.plot(f, g)
plt.xlabel("f")
plt.ylabel("g (tanh)")
# Out:
# [-1.         -0.99999999 -0.99999998 -0.99999995 -0.99999989 -0.99999976
#  -0.99999945 -0.99999875 -0.99999717 -0.9999936  -0.99998553 -0.99996727
#  -0.99992596 -0.99983253 -0.99962119 -0.99914327 -0.99806297 -0.99562344
#  -0.99012673 -0.97780324 -0.95048074 -0.89137347 -0.77003273 -0.54570541
#  -0.20129477  0.20129477  0.54570541  0.77003273  0.89137347  0.95048074
#   0.97780324  0.99012673  0.99562344  0.99806297  0.99914327  0.99962119
#   0.99983253  0.99992596  0.99996727  0.99998553  0.9999936   0.99999717
#   0.99999875  0.99999945  0.99999976  0.99999989  0.99999995  0.99999998
#   0.99999999  1.        ]
# Text(0, 0.5, 'g (tanh)')

# %%
def relu(f):
  return np.maximum(f, 0)

g = relu(f)
plt.plot(f, g)
plt.xlabel("f")
plt.ylabel("g (relu)")
# Out:
# Text(0, 0.5, 'g (relu)')
